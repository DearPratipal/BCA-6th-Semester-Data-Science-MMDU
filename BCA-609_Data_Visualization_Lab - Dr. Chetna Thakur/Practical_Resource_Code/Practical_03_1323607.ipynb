# %% [markdown]
# ### Program No. 03.  >> Data Representation vs Data Presentation

# %% [markdown]
# Tasks:
# 1. Represent the same dataset using at least two different chart types
# 2. Compare clarity and interpretation
#
# Outcome: Students will be able to choose appropriate visualization techniques.

# %% [markdown]
# Import dependecies library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load the Dataset

# %%
file = "Uncleaned_Student_Dataset.csv"
df = pd.read_csv(file)
df.head()
# Out:
#    student_id roll_number department program academic_year course_code  \
# 0         176        R113        BCA     NaN       2023-24       ML401
# 1         197         R28         ME   MTech       2024-25       IT305
# 2          26         R16        ECE     MBA       2024-25         NaN
# 3          68        R108        CSE     MBA       2022-23       WD210
# 4         212         R32      Civil   MTech           NaN         NaN
#
#    attendance_percentage  internal_marks  external_marks  sgpa  gender   age  \
# 0                  82.00            22.2            41.6   NaN  Female  18.0
# 1                  42.37            37.3            30.8  6.57       M  19.0
# 2                  49.78             NaN            63.9  5.54    Male   NaN
# 3                  85.46            26.7            53.4  9.64       M  18.0
# 4                  92.36             NaN            60.4  6.01  female   NaN
#
#   study_hours
# 0           5
# 1         NaN
# 2           1
# ...

# %% [markdown]
# Performe the Operation

# %%
df_rep = df[['department', 'sgpa']].copy()

# %%
df_rep['sgpa'] = pd.to_numeric(df_rep['sgpa'], errors='coerce')
df_rep = df_rep.dropna()

# %% [markdown]
# Group Data (Department-wise Average SGPA)

# %%
dept_avg = (
    df_rep
    .groupby('department')['sgpa']
    .mean()
    .reset_index()
)
dept_avg
# Out:
#      department      sgpa
# 0           BCA  6.913333
# 1           CSE  6.827368
# 2         Civil  7.028333
# 3  Data Science  6.629333
# 4           ECE  6.480000
# 5            IT  6.740000
# 6           MCA  7.078333
# 7            ME  7.382000

# %% [markdown]
# #### Data Representation (Bar Chart)

# %% [markdown]
# Bar Chart – Clear Comparison

# %%
plt.figure(figsize=(8,5))
plt.bar(dept_avg['department'], dept_avg['sgpa'], color='skyblue')
plt.xlabel("Department")
plt.ylabel("Average SGPA")
plt.title("Data Representation: Department-wise Average SGPA (Bar Chart)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Pie Chart – Visual Presentation

# %%
plt.figure(figsize=(6,6))
plt.pie(
    dept_avg['sgpa'],
    labels= dept_avg['department'], # type: ignore
    autopct='%1.1f%%',
    startangle=140
)
plt.title("Data Presentation: Department-wise SGPA Distribution (Pie Chart)")
plt.show()
